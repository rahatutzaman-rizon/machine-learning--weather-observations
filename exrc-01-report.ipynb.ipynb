# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Weather--/weather_2020-11.csv')
df
# Out:
#                       Time   ParameterName ParameterValue
# 0     2020-11-01T00:00:00Z     TA_PT1H_AVG            6.5
# 1     2020-11-01T00:00:00Z     TA_PT1H_MAX            6.6
# 2     2020-11-01T00:00:00Z     TA_PT1H_MIN            6.3
# 3     2020-11-01T00:00:00Z     RH_PT1H_AVG           95.0
# 4     2020-11-01T00:00:00Z     WS_PT1H_AVG            3.3
# ...                    ...             ...            ...
# 8359  2020-11-30T00:00:00Z     WD_PT1H_AVG          138.0
# 8360  2020-11-30T00:00:00Z    PRA_PT1H_ACC            NaN
# 8361  2020-11-30T00:00:00Z    PRI_PT1H_MAX            NaN
# 8362  2020-11-30T00:00:00Z     PA_PT1H_AVG         1026.9
# 8363  2020-11-30T00:00:00Z  WAWA_PT1H_RANK            NaN
#
# [8364 rows x 3 columns]

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('/content/drive/MyDrive/Weather--/weather_2020-11.csv')

# Display the first 5 rows of the DataFrame
print(df.head())
# Out:
#                    Time ParameterName ParameterValue
# 0  2020-11-01T00:00:00Z   TA_PT1H_AVG            6.5
# 1  2020-11-01T00:00:00Z   TA_PT1H_MAX            6.6
# 2  2020-11-01T00:00:00Z   TA_PT1H_MIN            6.3
# 3  2020-11-01T00:00:00Z   RH_PT1H_AVG           95.0
# 4  2020-11-01T00:00:00Z   WS_PT1H_AVG            3.3

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('/content/drive/MyDrive/Weather--/weather_2020-11.csv')

# Get all parameter names
parameter_names = df.columns.tolist()

# Print all parameter names
print("All Parameter Names:")
for param in parameter_names:
    print(param)
# Out:
# All Parameter Names:
# Time
# ParameterName
# ParameterValue

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('/content/drive/MyDrive/Weather--/weather_2020-11.csv')

# Remove rows with null values
df_cleaned = df.dropna()

# Display the cleaned DataFrame
print(df_cleaned)
# Out:
#                       Time ParameterName ParameterValue
# 0     2020-11-01T00:00:00Z   TA_PT1H_AVG            6.5
# 1     2020-11-01T00:00:00Z   TA_PT1H_MAX            6.6
# 2     2020-11-01T00:00:00Z   TA_PT1H_MIN            6.3
# 3     2020-11-01T00:00:00Z   RH_PT1H_AVG           95.0
# 4     2020-11-01T00:00:00Z   WS_PT1H_AVG            3.3
# ...                    ...           ...            ...
# 8356  2020-11-30T00:00:00Z   WS_PT1H_AVG            1.7
# 8357  2020-11-30T00:00:00Z   WS_PT1H_MAX            2.2
# 8358  2020-11-30T00:00:00Z   WS_PT1H_MIN            1.1
# 8359  2020-11-30T00:00:00Z   WD_PT1H_AVG          138.0
# 8362  2020-11-30T00:00:00Z   PA_PT1H_AVG         1026.9
#
# [6229 rows x 3 columns]

# %% [markdown]
# **2.Calculate the average values**

# %%
import csv

def calculate_avg_from_csv(filename):
    total = 0
    count = 0

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("TA"):
                total += float(row['ParameterValue'])
                count += 1

    if count == 0:
        return 0
    return total / count

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
result = calculate_avg_from_csv(filename)
print(f"Average of 'perimeter value' where 'peremeter name' starts with 'TA': {result}")
# Out:
# Average of 'perimeter value' where 'peremeter name' starts with 'TA': 2.7347202295552404

# %%
import csv
import numpy as np  # Import numpy for NaN handling

def calculate_avg_from_csv(filename):
    total = 0
    count = 0

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("RH"):  # Change 'TA' to 'RH'
                try:
                    value = float(row['ParameterValue'])
                    if not np.isnan(value):  # Check if value is not NaN
                        total += value
                        count += 1
                except ValueError:
                    pass  # Skip non-numeric values

    if count == 0:
        return 0
    return total / count

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
result = calculate_avg_from_csv(filename)
print(f"Average of 'ParameterValue' where 'ParameterName' starts with 'RH': {result}")
# Out:
# Average of 'ParameterValue' where 'ParameterName' starts with 'RH': 87.90138674884437

# %%
import csv

def calculate_avg_from_csv(filename):
    total = 0
    count = 0

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("WS"):
                total += float(row['ParameterValue'])
                count += 1

    if count == 0:
        return 0
    return total / count

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
result = calculate_avg_from_csv(filename)
print(f"Average of 'ParameterValue' where 'ParameterName' starts with 'WS': {result}")
# Out:
# Average of 'ParameterValue' where 'ParameterName' starts with 'WS': 3.9195121951219534

# %%
import csv
import numpy as np

def calculate_avg_from_csv(filename):
    total = 0
    count = 0

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("PAR"):  # Changed 'RH' to 'PAR'
                try:
                    value = float(row['ParameterValue'])
                    if not np.isnan(value):  # Check for NaN values
                        total += value
                        count += 1
                except ValueError:
                    pass  # Skip non-numeric values

    if count == 0:
        return 0
    return total / count

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
result = calculate_avg_from_csv(filename)
print(f"Average of 'ParameterValue' where 'ParameterName' starts with 'PAR' after handling NaN values: {result}")
# Out:
# Average of 'ParameterValue' where 'ParameterName' starts with 'PAR' after handling NaN values: 0

# %%
import csv

def calculate_avg_from_csv(filename):
    total = 0
    count = 0

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("PA"):
                total += float(row['ParameterValue'])
                count += 1

    if count == 0:
        return 0
    return total / count

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
result = calculate_avg_from_csv(filename)
print(f"Average of 'ParameterValue' where 'ParameterName' starts with 'PA': {result}")
# Out:
# Average of 'ParameterValue' where 'ParameterName' starts with 'PA': 1012.6341463414637

# %% [markdown]
# **3.For each parameter, calculate the minimum, maximum, and median values.**

# %%
import csv
import numpy as np

def calculate_stats_from_csv(filename):
    values = []

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("TA"):
                try:
                    value = float(row['ParameterValue'])
                    values.append(value)
                except ValueError:
                    pass  # Skip non-numeric values

    if values:
        min_val = np.min(values)
        max_val = np.max(values)
        median_val = np.median(values)
        return min_val, max_val, median_val
    else:
        return None, None, None

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
min_val, max_val, median_val = calculate_stats_from_csv(filename)
if min_val is not None:
    print(f"Minimum value: {min_val}")
    print(f"Maximum value: {max_val}")
    print(f"Median value: {median_val}")
else:
    print("No valid values found for the specified criteria.")
# Out:
# Minimum value: -9.1
# Maximum value: 11.1
# Median value: 2.7

# %%
import csv
import numpy as np

def calculate_stats_from_csv(filename):
    values = []

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("RH"):  # Changed 'PA' to 'RH'
                try:
                    value = float(row['ParameterValue'])
                    if not np.isnan(value):  # Check for NaN values
                        values.append(value)
                except ValueError:
                    pass  # Skip non-numeric values

    if values:
        min_val = np.min(values)
        max_val = np.max(values)
        median_val = np.median(values)
        return min_val, max_val, median_val
    else:
        return None, None, None

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
min_val, max_val, median_val = calculate_stats_from_csv(filename)
if min_val is not None:
    print(f"Minimum value: {min_val}")
    print(f"Maximum value: {max_val}")
    print(f"Median value: {median_val}")
else:
    print("No valid values found for the specified criteria.")
# Out:
# Minimum value: 61.0
# Maximum value: 100.0
# Median value: 89.0

# %%
import csv
import numpy as np

def calculate_stats_from_csv(filename):
    values = []

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("PA"):  # Changed 'TA' to 'PA'
                try:
                    value = float(row['ParameterValue'])
                    values.append(value)
                except ValueError:
                    pass  # Skip non-numeric values

    if values:
        min_val = np.min(values)
        max_val = np.max(values)
        median_val = np.median(values)
        return min_val, max_val, median_val
    else:
        return None, None, None

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
min_val, max_val, median_val = calculate_stats_from_csv(filename)
if min_val is not None:
    print(f"Minimum value: {min_val}")
    print(f"Maximum value: {max_val}")
    print(f"Median value: {median_val}")
else:
    print("No valid values found for the specified criteria.")
# Out:
# Minimum value: 977.3
# Maximum value: 1032.6
# Median value: 1013.7

# %%
import csv
import numpy as np

def calculate_stats_from_csv(filename):
    values = []

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("PRA"):  # Changed 'PA' to 'RH'
                try:
                    value = float(row['ParameterValue'])
                    if not np.isnan(value):  # Check for NaN values
                        values.append(value)
                except ValueError:
                    pass  # Skip non-numeric values

    if values:
        min_val = np.min(values)
        max_val = np.max(values)
        median_val = np.median(values)
        return min_val, max_val, median_val
    else:
        return 0, 0, 0  # Return default values of 0 if no valid values are found

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
min_val, max_val, median_val = calculate_stats_from_csv(filename)
print(f"Minimum value: {min_val}")
print(f"Maximum value: {max_val}")
print(f"Median value: {median_val}")
# Out:
# Minimum value: 0
# Maximum value: 0
# Median value: 0

# %% [markdown]
# **Find the hour with the highest value for each parameter.**

# %%
import csv

def calculate_highest_value_from_csv(filename):
    highest_value = None

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("TA"):
                try:
                    value = float(row['ParameterValue'])
                    if highest_value is None or value > highest_value:
                        highest_value = value
                except ValueError:
                    pass  # Skip non-numeric values

    return highest_value

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
highest_value = calculate_highest_value_from_csv(filename)
if highest_value is not None:
    print(f"Highest value: {highest_value}")
else:
    print("No valid values found for the specified criteria.")
# Out:
# Highest value: 11.1

# %%
import csv
import numpy as np

def calculate_highest_value_from_csv(filename):
    highest_value = None

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("RH"):  # Change 'TA' to 'RH'
                try:
                    value = float(row['ParameterValue'])
                    if not np.isnan(value):  # Check for NaN values
                        if highest_value is None or value > highest_value:
                            highest_value = value
                except ValueError:
                    pass  # Skip non-numeric values

    return highest_value

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
highest_value = calculate_highest_value_from_csv(filename)
if highest_value is not None:
    print(f"Highest value: {highest_value}")
else:
    print("No valid values found for the specified criteria.")
# Out:
# Highest value: 100.0

# %%
import csv

def calculate_highest_value_from_csv(filename):
    highest_value = None

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("PA"):
                try:
                    value = float(row['ParameterValue'])
                    if highest_value is None or value > highest_value:
                        highest_value = value
                except ValueError:
                    pass  # Skip non-numeric values

    return highest_value

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
highest_value = calculate_highest_value_from_csv(filename)
if highest_value is not None:
    print(f"Highest value: {highest_value}")
else:
    print("No valid values found for the specified criteria.")
# Out:
# Highest value: 1032.6

# %%
import csv
import numpy as np

def calculate_highest_value_from_csv(filename):
    highest_value = None  # Initialize highest value variable

    with open(filename, 'r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row['ParameterName'].startswith("PRA"):  # Changed 'PA' to 'RH'
                try:
                    value = float(row['ParameterValue'])
                    if not np.isnan(value):  # Check for NaN values
                        # Update highest value if the current value is higher
                        if highest_value is None or value > highest_value:
                            highest_value = value
                except ValueError:
                    pass  # Skip non-numeric values

    return highest_value if highest_value is not None else 0  # Return 0 if no valid values are found

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
highest_val = calculate_highest_value_from_csv(filename)
print(f"Highest value: {highest_val}")
# Out:
# Highest value: 0

# %% [markdown]
# **4.Create plots to visualize the trends of the following parameters over time**

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_parameter_trends(filename):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(filename)

    # Filter rows where 'ParameterName' starts with 'TA'
    df_ta = df[df['ParameterName'].str.startswith('TA')]

    # Convert 'Time' column to datetime
    df_ta['Time'] = pd.to_datetime(df_ta['Time'])

    # Set 'Time' column as index
    df_ta.set_index('Time', inplace=True)

    # Plot parameter trends over time
    plt.figure(figsize=(10, 6))
    for parameter_name in df_ta['ParameterName'].unique():
        plt.plot(df_ta.loc[df_ta['ParameterName'] == parameter_name].index,
                 df_ta.loc[df_ta['ParameterName'] == parameter_name, 'ParameterValue'],
                 label=parameter_name)
    plt.xlabel('Time')
    plt.ylabel('Parameter Value')
    plt.title('Parameter Trends Over Time')
    plt.legend()
    plt.show()

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
plot_parameter_trends(filename)
# Out:
# <ipython-input-96-5776190ae2bc>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ta['Time'] = pd.to_datetime(df_ta['Time'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_parameter_trends(filename):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(filename)

    # Filter rows where 'ParameterName' starts with 'RH'
    df_rh = df[df['ParameterName'].str.startswith('RH')]

    # Convert 'Time' column to datetime
    df_rh['Time'] = pd.to_datetime(df_rh['Time'])

    # Set 'Time' column as index
    df_rh.set_index('Time', inplace=True)

    # Drop rows with NaN values in 'ParameterValue' column
    df_rh.dropna(subset=['ParameterValue'], inplace=True)

    # Plot parameter trends over time
    plt.figure(figsize=(10, 6))
    for parameter_name in df_rh['ParameterName'].unique():
        plt.plot(df_rh.loc[df_rh['ParameterName'] == parameter_name].index,
                 df_rh.loc[df_rh['ParameterName'] == parameter_name, 'ParameterValue'],
                 label=parameter_name)
    plt.xlabel('Time')
    plt.ylabel('Parameter Value')
    plt.title('Parameter Trends Over Time')
    plt.legend()
    plt.show()

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
plot_parameter_trends(filename)
# Out:
# <ipython-input-97-9b595d23e0b3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rh['Time'] = pd.to_datetime(df_rh['Time'])
# <ipython-input-97-9b595d23e0b3>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rh.dropna(subset=['ParameterValue'], inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_parameter_trends(filename):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(filename)

    # Filter rows where 'ParameterName' starts with 'PA'
    df_pa = df[df['ParameterName'].str.startswith('PA')]

    # Convert 'Time' column to datetime
    df_pa['Time'] = pd.to_datetime(df_pa['Time'])

    # Set 'Time' column as index
    df_pa.set_index('Time', inplace=True)

    # Plot parameter trends over time
    plt.figure(figsize=(10, 6))
    for parameter_name in df_pa['ParameterName'].unique():
        plt.plot(df_pa.loc[df_pa['ParameterName'] == parameter_name].index,
                 df_pa.loc[df_pa['ParameterName'] == parameter_name, 'ParameterValue'],
                 label=parameter_name)
    plt.xlabel('Time')
    plt.ylabel('Parameter Value')
    plt.title('Parameter Trends Over Time')
    plt.legend()
    plt.show()

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
plot_parameter_trends(filename)
# Out:
# <ipython-input-98-492aa822a30d>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pa['Time'] = pd.to_datetime(df_pa['Time'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def plot_parameter_trends(filename):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(filename)

    # Filter rows where 'ParameterName' starts with 'PRA'
    df_pra = df[df['ParameterName'].str.startswith('PRA')]

    # Convert 'Time' column to datetime
    df_pra['Time'] = pd.to_datetime(df_pra['Time'])

    # Set 'Time' column as index
    df_pra.set_index('Time', inplace=True)

    # Handle NaN values
    df_pra['ParameterValue'] = pd.to_numeric(df_pra['ParameterValue'], errors='coerce')

    # Plot parameter trends over time
    plt.figure(figsize=(10, 6))
    for parameter_name in df_pra['ParameterName'].unique():
        plt.plot(df_pra.loc[df_pra['ParameterName'] == parameter_name].index,
                 df_pra.loc[df_pra['ParameterName'] == parameter_name, 'ParameterValue'],
                 label=parameter_name)
    plt.xlabel('Time')
    plt.ylabel('Parameter Value')
    plt.title('Parameter Trends Over Time')
    plt.legend()
    plt.show()

# Example usage:
filename = '/content/drive/MyDrive/Weather--/weather_2020-11.csv'
plot_parameter_trends(filename)
# Out:
# <ipython-input-99-6a0c040447b5>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pra['Time'] = pd.to_datetime(df_pra['Time'])
# <ipython-input-99-6a0c040447b5>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pra['ParameterValue'] = pd.to_numeric(df_pra['ParameterValue'], errors='coerce')
